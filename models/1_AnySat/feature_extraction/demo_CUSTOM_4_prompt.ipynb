# %%
import psutil

# Get virtual memory details
mem_info = psutil.virtual_memory()

total_ram_gb = mem_info.total / 1e9
available_ram_gb = mem_info.available / 1e9

print(f"Total RAM limit: {total_ram_gb:.1f} GB")
print(f"Currently available RAM: {available_ram_gb:.1f} GB")
# Out:
# Total RAM limit: 54.8 GB
# Currently available RAM: 53.1 GB

# %%
### Check for connected runtime (GPU or not)
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jun  8 14:37:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
### Check for more RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
print("CUDA available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1191/753754918.py in <cell line: 0>()
# ----> 1 print("CUDA available:", torch.cuda.is_available())
#       2 print("Device name:", torch.cuda.get_device_name(0))
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ##### Mount Drive into Collab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### Path to Model Repository

# %%
# %cd /content/drive/MyDrive/master_thesis_FM/models/1_AnySat/feature_extraction/
# Out:
# /content/drive/MyDrive/master_thesis_FM/models/1_AnySat/feature_extraction

# %% [markdown]
# ##### Installing Model requirements

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.26.0+cu128)
# Collecting lightning>=2.0.0 (from -r requirements.txt (line 4))
#   Downloading lightning-2.6.5-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.6 MB/s eta 0:00:00
# Collecting torchmetrics>=0.11.4 (from -r requirements.txt (line 5))
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Collecting hydra-core==1.3.2 (from -r requirements.txt (line 8))
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting hydra-colorlog==1.2.0 (from -r requirements.txt (line 9))
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# Collecting hydra-optuna-sweeper==1.2.0 (from -r requirements.txt (line 10))
#   Downloading hydra_optuna_sweeper-1.2.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.27.0)
# Collecting pyrootutils (from -r requirements.txt (line 20))
#   Downloading pyrootutils-1.0.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting pre-commit (from -r requirements.txt (line 21))
#   Downloading pre_commit-4.6.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (13.9.4)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (8.4.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (3.16.0)
# Collecting scikit-multilearn (from -r requirements.txt (line 25))
#   Downloading scikit_multilearn-0.2.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (1.6.1)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (1.5.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (1.0.27)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (1.13)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 30)) (1.1.3)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core==1.3.2->-r requirements.txt (line 8)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core==1.3.2->-r requirements.txt (line 8)) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core==1.3.2->-r requirements.txt (line 8)) (26.2)
# Collecting colorlog (from hydra-colorlog==1.2.0->-r requirements.txt (line 9))
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting optuna<3.0.0,>=2.10.0 (from hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading optuna-2.10.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.15.0->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.15.0->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.0->-r requirements.txt (line 4)) (6.0.3)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0.0->-r requirements.txt (line 4))
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.0->-r requirements.txt (line 4)) (4.67.3)
# Collecting pytorch-lightning (from lightning>=2.0.0->-r requirements.txt (line 4))
#   Downloading pytorch_lightning-2.6.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (3.1.50)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 13)) (2.61.1)
# Requirement already satisfied: python-dotenv>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from pyrootutils->-r requirements.txt (line 20)) (1.2.2)
# Collecting cfgv>=2.0.0 (from pre-commit->-r requirements.txt (line 21))
#   Downloading cfgv-3.5.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting identify>=1.0.0 (from pre-commit->-r requirements.txt (line 21))
#   Downloading identify-2.6.19-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit->-r requirements.txt (line 21))
#   Downloading nodeenv-1.10.0-py2.py3-none-any.whl.metadata (24 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit->-r requirements.txt (line 21))
#   Downloading virtualenv-21.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r requirements.txt (line 22)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r requirements.txt (line 22)) (2.20.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->-r requirements.txt (line 23)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->-r requirements.txt (line 23)) (1.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 26)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 26)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 26)) (3.6.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->-r requirements.txt (line 27)) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->-r requirements.txt (line 27)) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio->-r requirements.txt (line 27)) (2026.5.20)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->-r requirements.txt (line 27)) (0.7.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio->-r requirements.txt (line 27)) (3.3.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 28)) (1.17.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 28)) (0.7.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->-r requirements.txt (line 30)) (0.12.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->-r requirements.txt (line 30)) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->-r requirements.txt (line 30)) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->-r requirements.txt (line 30)) (2.1.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->-r requirements.txt (line 2)) (1.5.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (3.14.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 13)) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 22)) (0.1.2)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (1.18.4)
# Collecting cliff (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading cliff-4.14.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting cmaes>=0.8.2 (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading cmaes-0.13.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (2.0.50)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->-r requirements.txt (line 30)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->-r requirements.txt (line 30)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->-r requirements.txt (line 30)) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb->-r requirements.txt (line 13)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb->-r requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 2)) (1.3.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit->-r requirements.txt (line 21))
#   Downloading distlib-0.4.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting python-discovery>=1.4 (from virtualenv>=20.10.0->pre-commit->-r requirements.txt (line 21))
#   Downloading python_discovery-1.4.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 28)) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 28)) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 28)) (0.25.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 4)) (1.24.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 13)) (5.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 28)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 28)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 28)) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas->-r requirements.txt (line 30)) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (3.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub->timm->-r requirements.txt (line 28)) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub->timm->-r requirements.txt (line 28)) (0.0.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (1.3.12)
# Collecting autopage>=0.4.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading autopage-0.6.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting cmd2>=3.0.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading cmd2-4.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (3.17.0)
# Collecting stevedore>=5.6.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading stevedore-5.8.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.52 in /usr/local/lib/python3.12/dist-packages (from cmd2>=3.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (3.0.52)
# Requirement already satisfied: pyperclip>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from cmd2>=3.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (1.11.0)
# Collecting rich (from -r requirements.txt (line 22))
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting rich-argparse>=1.7.2 (from cmd2>=3.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10))
#   Downloading rich_argparse-1.8.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from PrettyTable>=0.7.2->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r requirements.txt (line 10)) (0.7.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 18.7 MB/s eta 0:00:00
# Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Downloading hydra_optuna_sweeper-1.2.0-py3-none-any.whl (8.5 kB)
# Downloading lightning-2.6.5-py3-none-any.whl (848 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 65.3 MB/s eta 0:00:00
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 67.2 MB/s eta 0:00:00
# Downloading pyrootutils-1.0.4-py3-none-any.whl (5.8 kB)
# Downloading pre_commit-4.6.0-py2.py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 kB 28.7 MB/s eta 0:00:00
# Downloading scikit_multilearn-0.2.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 11.6 MB/s eta 0:00:00
# Downloading cfgv-3.5.0-py2.py3-none-any.whl (7.4 kB)
# Downloading identify-2.6.19-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 13.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading nodeenv-1.10.0-py2.py3-none-any.whl (23 kB)
# Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 36.1 MB/s eta 0:00:00
# Downloading virtualenv-21.4.2-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 157.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading pytorch_lightning-2.6.5-py3-none-any.whl (852 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 68.0 MB/s eta 0:00:00
# Downloading cmaes-0.13.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/73.0 kB 9.1 MB/s eta 0:00:00
# Downloading distlib-0.4.1-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.2/469.2 kB 44.6 MB/s eta 0:00:00
# Downloading python_discovery-1.4.0-py3-none-any.whl (33 kB)
# Downloading cliff-4.14.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 12.0 MB/s eta 0:00:00
# Downloading autopage-0.6.0-py3-none-any.whl (30 kB)
# Downloading cmd2-4.0.0-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.5/180.5 kB 24.7 MB/s eta 0:00:00
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 37.1 MB/s eta 0:00:00
# Downloading stevedore-5.8.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 7.1 MB/s eta 0:00:00
# Downloading rich_argparse-1.8.0-py3-none-any.whl (25 kB)
# Installing collected packages: scikit-multilearn, distlib, stevedore, python-discovery, pyrootutils, nodeenv, lightning-utilities, identify, colorlog, cmaes, cfgv, autopage, virtualenv, rich, hydra-core, rich-argparse, pre-commit, hydra-colorlog, cmd2, torchmetrics, cliff, pytorch-lightning, optuna, lightning, hydra-optuna-sweeper
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.41.0 requires rich<14,>=12.4.4, but you have rich 15.0.0 which is incompatible.
# pyiceberg 0.11.1 requires rich<15.0.0,>=10.11.0, but you have rich 15.0.0 which is incompatible.
# Successfully installed autopage-0.6.0 cfgv-3.5.0 cliff-4.14.0 cmaes-0.13.0 cmd2-4.0.0 colorlog-6.10.1 distlib-0.4.1 hydra-colorlog-1.2.0 hydra-core-1.3.2 hydra-optuna-sweeper-1.2.0 identify-2.6.19 lightning-2.6.5 lightning-utilities-0.15.3 nodeenv-1.10.0 optuna-2.10.1 pre-commit-4.6.0 pyrootutils-1.0.4 python-discovery-1.4.0 pytorch-lightning-2.6.5 rich-15.0.0 rich-argparse-1.8.0 scikit-multilearn-0.2.0 stevedore-5.8.0 torchmetrics-1.9.0 virtualenv-21.4.2

# %% [markdown]
# # [ORIGINAL PART]

# %% [markdown]
# # AnySat Guide

# %% [markdown]
# #### Simple Usage

# %%
import os
import torch
from torch.utils.data import DataLoader, Dataset
import numpy as np
import rasterio
from datetime import datetime
import h5py
import time
import psutil
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ## AnySat is available through
# ### 1) PyTorch Hub
# #### or
# ### 2) local repository

# %%
# 1) PyTorch Hub
#model = torch.hub.load('gastruc/anysat', 'anysat', pretrained=True, force_reload=True, flash_attn=False, trust_repo='check')

# 2) local repo
from hubconf import AnySat

model = AnySat.from_pretrained('base', flash_attn=False) #Set flash_attn=True if you have flash-attn module installed (url flash attn)
#device = "cuda" If you want to run on GPU default is cpu
# Out:
# Downloading: "https://huggingface.co/g-astruc/AnySat/resolve/main/models/AnySat.pth" to /root/.cache/torch/hub/checkpoints/AnySat.pth
# 100%|██████████| 480M/480M [00:21<00:00, 23.2MB/s]

# %% [markdown]
# ### Added code to assure that every part of the Model runs on GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the entire model and its submodules to the GPU
model = model.to(device)

# Iterate through all model parameters and move them to the GPU if not already there
for param in model.parameters():
    if param.device != device:
        param.data = param.data.to(device)

# Check for any remaining submodules not on the GPU
for name, module in model.named_modules():
    if next(module.parameters(), None) is not None and next(module.parameters()).device != device:  # Checks if module has parameters
        module.to(device)
        print(f"Module '{name}' moved to {device}")
# Out:
# Module '' moved to cuda
# Module 'spatial_encoder' moved to cuda
# Module 'spatial_encoder.predictor_blocks' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.norm1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.attn' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.attn.qkv' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.attn.proj' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.attn.rpe_k' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.norm2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.mlp' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.mlp.fc1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.0.mlp.fc2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.norm1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.attn' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.attn.qkv' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.attn.proj' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.attn.rpe_k' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.norm2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.mlp' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.mlp.fc1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.1.mlp.fc2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.norm1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.attn' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.attn.qkv' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.attn.proj' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.attn.rpe_k' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.norm2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.mlp' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.mlp.fc1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.2.mlp.fc2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.norm1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.attn' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.attn.qkv' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.attn.proj' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.attn.rpe_k' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.norm2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.mlp' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.mlp.fc1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.3.mlp.fc2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.norm1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.attn' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.attn.qkv' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.attn.proj' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.attn.rpe_k' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.norm2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.mlp' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.mlp.fc1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.4.mlp.fc2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.norm1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.attn' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.attn.qkv' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.attn.proj' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.attn.rpe_k' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.norm2' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.mlp' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.mlp.fc1' moved to cuda
# Module 'spatial_encoder.predictor_blocks.5.mlp.fc2' moved to cuda
# Module 'spatial_encoder.predictor_norm' moved to cuda
# Module 'model' moved to cuda
# Module 'model.projector_aerial' moved to cuda
# Module 'model.projector_aerial.patch_embed' moved to cuda
# Module 'model.projector_aerial.mlp' moved to cuda
# Module 'model.projector_aerial.mlp.0' moved to cuda
# Module 'model.projector_aerial.mlp.1' moved to cuda
# Module 'model.projector_aerial.mlp.3' moved to cuda
# Module 'model.projector_aerial.mlp.4' moved to cuda
# Module 'model.projector_aerial-flair' moved to cuda
# Module 'model.projector_aerial-flair.patch_embed' moved to cuda
# Module 'model.projector_aerial-flair.mlp' moved to cuda
# Module 'model.projector_aerial-flair.mlp.0' moved to cuda
# Module 'model.projector_aerial-flair.mlp.1' moved to cuda
# Module 'model.projector_aerial-flair.mlp.3' moved to cuda
# Module 'model.projector_aerial-flair.mlp.4' moved to cuda
# Module 'model.projector_alos' moved to cuda
# Module 'model.projector_alos.patch_embed' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_alos.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_alos.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_alos.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_alos.patch_embed.out_norm' moved to cuda
# Module 'model.projector_alos.patch_embed.mlp' moved to cuda
# Module 'model.projector_alos.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_alos.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_l7' moved to cuda
# Module 'model.projector_l7.patch_embed' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_l7.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_l7.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_l7.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_l7.patch_embed.out_norm' moved to cuda
# Module 'model.projector_l7.patch_embed.mlp' moved to cuda
# Module 'model.projector_l7.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_l7.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_l8' moved to cuda
# Module 'model.projector_l8.patch_embed' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_l8.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_l8.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_l8.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_l8.patch_embed.out_norm' moved to cuda
# Module 'model.projector_l8.patch_embed.mlp' moved to cuda
# Module 'model.projector_l8.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_l8.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_modis' moved to cuda
# Module 'model.projector_modis.patch_embed' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_modis.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_modis.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_modis.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_modis.patch_embed.out_norm' moved to cuda
# Module 'model.projector_modis.patch_embed.mlp' moved to cuda
# Module 'model.projector_modis.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_modis.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_naip' moved to cuda
# Module 'model.projector_naip.patch_embed' moved to cuda
# Module 'model.projector_naip.mlp' moved to cuda
# Module 'model.projector_naip.mlp.0' moved to cuda
# Module 'model.projector_naip.mlp.1' moved to cuda
# Module 'model.projector_naip.mlp.3' moved to cuda
# Module 'model.projector_naip.mlp.4' moved to cuda
# Module 'model.projector_s1' moved to cuda
# Module 'model.projector_s1.patch_embed' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_s1.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_s1.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_s1.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_s1.patch_embed.out_norm' moved to cuda
# Module 'model.projector_s1.patch_embed.mlp' moved to cuda
# Module 'model.projector_s1.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_s1.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_s1-asc' moved to cuda
# Module 'model.projector_s1-asc.patch_embed' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.out_norm' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.mlp' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_s1-asc.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_s2' moved to cuda
# Module 'model.projector_s2.patch_embed' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.0' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.1' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.4' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.5' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.8' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.9' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.12' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.13' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.16' moved to cuda
# Module 'model.projector_s2.patch_embed.inconv.17' moved to cuda
# Module 'model.projector_s2.patch_embed.attention_heads' moved to cuda
# Module 'model.projector_s2.patch_embed.attention_heads.fc1_k' moved to cuda
# Module 'model.projector_s2.patch_embed.in_norm' moved to cuda
# Module 'model.projector_s2.patch_embed.out_norm' moved to cuda
# Module 'model.projector_s2.patch_embed.mlp' moved to cuda
# Module 'model.projector_s2.patch_embed.mlp.0' moved to cuda
# Module 'model.projector_s2.patch_embed.mlp.1' moved to cuda
# Module 'model.projector_spot' moved to cuda
# Module 'model.projector_spot.patch_embed' moved to cuda
# Module 'model.projector_spot.mlp' moved to cuda
# Module 'model.projector_spot.mlp.0' moved to cuda
# Module 'model.projector_spot.mlp.1' moved to cuda
# Module 'model.projector_spot.mlp.3' moved to cuda
# Module 'model.projector_spot.mlp.4' moved to cuda
# Module 'model.blocks' moved to cuda
# Module 'model.blocks.0' moved to cuda
# Module 'model.blocks.0.norm1' moved to cuda
# Module 'model.blocks.0.attn' moved to cuda
# Module 'model.blocks.0.attn.qkv' moved to cuda
# Module 'model.blocks.0.attn.proj' moved to cuda
# Module 'model.blocks.0.norm2' moved to cuda
# Module 'model.blocks.0.mlp' moved to cuda
# Module 'model.blocks.0.mlp.fc1' moved to cuda
# Module 'model.blocks.0.mlp.fc2' moved to cuda
# Module 'model.blocks.1' moved to cuda
# Module 'model.blocks.1.norm1' moved to cuda
# Module 'model.blocks.1.attn' moved to cuda
# Module 'model.blocks.1.attn.qkv' moved to cuda
# Module 'model.blocks.1.attn.proj' moved to cuda
# Module 'model.blocks.1.norm2' moved to cuda
# Module 'model.blocks.1.mlp' moved to cuda
# Module 'model.blocks.1.mlp.fc1' moved to cuda
# Module 'model.blocks.1.mlp.fc2' moved to cuda
# Module 'model.blocks.2' moved to cuda
# Module 'model.blocks.2.norm1' moved to cuda
# Module 'model.blocks.2.attn' moved to cuda
# Module 'model.blocks.2.attn.qkv' moved to cuda
# Module 'model.blocks.2.attn.proj' moved to cuda
# Module 'model.blocks.2.norm2' moved to cuda
# Module 'model.blocks.2.mlp' moved to cuda
# Module 'model.blocks.2.mlp.fc1' moved to cuda
# Module 'model.blocks.2.mlp.fc2' moved to cuda
# Module 'model.blocks.3' moved to cuda
# Module 'model.blocks.3.norm1' moved to cuda
# Module 'model.blocks.3.attn' moved to cuda
# Module 'model.blocks.3.attn.qkv' moved to cuda
# Module 'model.blocks.3.attn.proj' moved to cuda
# Module 'model.blocks.3.norm2' moved to cuda
# Module 'model.blocks.3.mlp' moved to cuda
# Module 'model.blocks.3.mlp.fc1' moved to cuda
# Module 'model.blocks.3.mlp.fc2' moved to cuda
# Module 'model.blocks.4' moved to cuda
# Module 'model.blocks.4.norm1' moved to cuda
# Module 'model.blocks.4.attn' moved to cuda
# Module 'model.blocks.4.attn.qkv' moved to cuda
# Module 'model.blocks.4.attn.proj' moved to cuda
# Module 'model.blocks.4.norm2' moved to cuda
# Module 'model.blocks.4.mlp' moved to cuda
# Module 'model.blocks.4.mlp.fc1' moved to cuda
# Module 'model.blocks.4.mlp.fc2' moved to cuda
# Module 'model.blocks.5' moved to cuda
# Module 'model.blocks.5.norm1' moved to cuda
# Module 'model.blocks.5.attn' moved to cuda
# Module 'model.blocks.5.attn.qkv' moved to cuda
# Module 'model.blocks.5.attn.proj' moved to cuda
# Module 'model.blocks.5.norm2' moved to cuda
# Module 'model.blocks.5.mlp' moved to cuda
# Module 'model.blocks.5.mlp.fc1' moved to cuda
# Module 'model.blocks.5.mlp.fc2' moved to cuda
# Module 'model.blocks.6' moved to cuda
# Module 'model.blocks.6.norm1' moved to cuda
# Module 'model.blocks.6.attn' moved to cuda
# Module 'model.blocks.6.attn.wk' moved to cuda
# Module 'model.blocks.6.attn.wv' moved to cuda
# Module 'model.blocks.6.attn.rpe_k' moved to cuda
# Module 'model.blocks.6.attn.proj' moved to cuda
# Module 'model.blocks.6.norm2' moved to cuda
# Module 'model.blocks.6.mlp' moved to cuda
# Module 'model.blocks.6.mlp.fc1' moved to cuda
# Module 'model.blocks.6.mlp.fc2' moved to cuda

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ### Complete Folder

# %%
import os
import torch
import glob
from tqdm.notebook import tqdm
from torch.utils.data import Dataset, DataLoader

# 🔧 Configuration
feature_set = 'test' # either 'train' or 'test'
ORBIT = 'asc'         # either 'asc' or 'desc'
OUTPUT_TYPE = 'dense' # Either 'tile', 'patch', 'dense'
CHANNELS = 3
SAMPLE_RATE = 6
BATCH_SIZE = 4
NUM_WORKERS = 8
PATCH_SIZE = 40
PRECISION_HALVING = True

# 📁 Paths
if CHANNELS == 3:
  CHANNEL_FOLDER = "3_channels_VV_VH_ratio"
elif CHANNELS == 2:
  CHANNEL_FOLDER = "2_channels_VV_VH"
else:
  raise ValueError("Invalid number of channels. Must be 2 or 3.")

if PRECISION_HALVING:
  PREC = "float16"
else:
  PREC = "float32"

INPUT_FOLDER = f"/content/drive/MyDrive/master_thesis_FM/datasets/BioMassters/s1_data/{feature_set}_partition/s1_july_pt_tensors/{CHANNEL_FOLDER}/{SAMPLE_RATE}%_subset_standardized"
OUTPUT_FOLDER = f"/content/drive/MyDrive/master_thesis_FM/datasets/BioMassters/s1_data/{feature_set}_partition/s1_july_pt_tensors/{CHANNEL_FOLDER}/Embedded_features/patch_size_{PATCH_SIZE}/{SAMPLE_RATE}%_subset_float16_TEST"

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
existing_outputs = set(os.listdir(OUTPUT_FOLDER))

model_used = model  # your pretrained model should already be defined

# 📦 Dataset
class TensorDataset(Dataset):
    def __init__(self, paths):
        self.paths = paths

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        path = self.paths[idx]
        tensor = torch.load(path).float()  # Shape: [# channels (2 or 3), 256, 256]
        filename = os.path.basename(path)
        return tensor, filename

# 📁 Load file paths
all_paths = sorted(glob.glob(os.path.join(INPUT_FOLDER, "*.pt")))

# Filter input tensor paths to exclude already-processed files
filtered_paths = []
for path in all_paths:
    original_name = os.path.basename(path)
    expected_output_name = f"Embedded_Features_OutputType{OUTPUT_TYPE.upper()}_PatchSize{PATCH_SIZE}_{original_name}"
    if expected_output_name not in existing_outputs:
        filtered_paths.append(path)

print(f"✅ {len(filtered_paths)} of {len(all_paths)} files will be processed (skipping existing ones)")

dataset = TensorDataset(filtered_paths)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# 📤 Inference & Save
with torch.no_grad():
    for batch, filenames in tqdm(loader, desc="Extracting features"):
        batch = batch.unsqueeze(1).to(device)  # [B, 1, # channels (2 or 3), 256, 256]
        dates = torch.tensor([196] * batch.shape[0]).to(device)

        data = {
            "s1": batch,
            "s1_dates": dates
        }

        # Feature batch output from your model
        batch_features = model_used(data, patch_size=PATCH_SIZE, output=OUTPUT_TYPE, output_modality = 's1')
        print(batch_features.shape)
        print(type(batch_features))

        # 💾 Save infered encoded features
        for i in range(len(filenames)):
            original_name = filenames[i]
            output_path = os.path.join(OUTPUT_FOLDER, f"Embedded_Features_OutputType{OUTPUT_TYPE.upper()}_PatchSize{PATCH_SIZE}_{original_name}")

            # Extrahiere den Tensor für das aktuelle Bild im Batch
            single_feature = batch_features[i].cpu()
            print(single_feature.shape)
            print(single_feature.dtype)
            print(single_feature.nbytes)
            print(type(single_feature))

            # --- NEUER SHAPE-CHECK ---
            expected_dims_sorted = [256, 256, 1536]
            if sorted(list(single_feature.shape)) != expected_dims_sorted:
                raise ValueError(
                    f"Abbruch! Unerwartete Shape bei Datei {original_name}.\n"
                    f"Erwartet: Permutation von {expected_dims_sorted}\n"
                    f"Erhalten: {list(single_feature.shape)}"
                )
            # -------------------------

            # Konvertiere den Tensor explizit zu float16 vor dem Speichern
            if PRECISION_HALVING:
                single_feature = single_feature.to(torch.float16)

            torch.save(single_feature, output_path)

        # 🧹 Memory cleanup
        del batch, filenames, data, batch_features, single_feature
        torch.cuda.empty_cache()

print("✅ All encoded features extracted and saved.")
# Out:
# ✅ 159 of 167 files will be processed (skipping existing ones)
# Extracting features:   0%|          | 0/40 [00:00<?, ?it/s]
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([4, 256, 256, 1536])
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>
# torch.Size([256, 256, 1536])
# torch.float32
# 402653184
# <class 'torch.Tensor'>

# %% [markdown]
# # Overflow check

# %%
import os
import torch
import glob
from tqdm.notebook import tqdm

# 📁 Passe den Pfad zu dem Ordner an, in dem deine 167 Dateien liegen
INPUT_FOLDER = f"/content/drive/MyDrive/Colab_Notebooks/Datasets/BioMassters/{feature_set}_features/S1_pytorch_tensors_{feature_set}_features/{CHANNEL_FOLDER}/Embedded_features/patch_size_{PATCH_SIZE}/{SAMPLE_RATE}%_EMBEDDED_{feature_set.upper()}_FEATURES_OutputType{OUTPUT_TYPE}_{ORBIT.upper()}_PatchSize{PATCH_SIZE}_float16"

# Liste aller .pt Dateien im Ordner abrufen
all_paths = sorted(glob.glob(os.path.join(INPUT_FOLDER, "*.pt")))
print(f"🔍 Prüfe {len(all_paths)} Dateien auf NaN oder Inf (Overflows)...")

problematic_files = []
files_with_nan = 0
files_with_inf = 0

# Iteriere durch alle Dateien
for path in tqdm(all_paths, desc="Checking Tensors"):
    try:
        # Datei laden (weights_only=True ist sicherer)
        tensor = torch.load(path, weights_only=True)

        has_nan = torch.isnan(tensor).any().item()
        has_inf = torch.isinf(tensor).any().item()

        if has_nan or has_inf:
            filename = os.path.basename(path)
            problematic_files.append({
                "file": filename,
                "nan": has_nan,
                "inf": has_inf
            })

            if has_nan: files_with_nan += 1
            if has_inf: files_with_inf += 1

        # Speicher sofort wieder freigeben
        del tensor

    except Exception as e:
        print(f"❌ Fehler beim Lesen von {os.path.basename(path)}: {e}")

# 📊 Ergebnisse ausgeben
print("\n" + "="*50)
if len(problematic_files) == 0:
    print("✅ Alles sauber! Keine Overflows (weder NaN noch Inf) in den 167 Dateien gefunden.")
else:
    print(f"⚠️ ACHTUNG: Probleme in {len(problematic_files)} Dateien gefunden!")
    print(f"👉 Davon mit NaN: {files_with_nan}")
    print(f"👉 Davon mit Inf (Overflow): {files_with_inf}\n")
    print("Betroffene Dateien (erste 10):")
    for info in problematic_files[:10]:
        print(f"- {info['file']} | NaN: {info['nan']} | Inf: {info['inf']}")
print("="*50)
# Out:
# 🔍 Prüfe 522 Dateien auf NaN oder Inf (Overflows)...
# Checking Tensors:   0%|          | 0/522 [00:00<?, ?it/s]
# ==================================================
# ✅ Alles sauber! Keine Overflows (weder NaN noch Inf) in den 167 Dateien gefunden.
# ==================================================
